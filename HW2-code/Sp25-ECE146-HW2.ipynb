# %%
import sys

# %%
# To add your own Drive Run this cell.
from google.colab import drive
drive.mount('/content/drive')

# %%
# Please append your own directory after ‘/content/drive/My Drive/'
# where you have nutil.py and adult_subsample.csv
### ========== TODO : START ========== ###
# for example: sys.path += ['/content/drive/My Drive/cs146/hw2'] 
### ========== TODO : END ========== ###

# %%
from nutil import *

# %%
# Use only the provided packages!
import math
import csv

from collections import Counter

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import learning_curve

# %%
######################################################################
# Immutatble classes
######################################################################

class Classifier(object) :
    """
    Classifier interface.
    """

    def fit(self, X, y):
        raise NotImplementedError()

    def predict(self, X):
        raise NotImplementedError()


class MajorityVoteClassifier(Classifier) :

    def __init__(self) :
        """
        A classifier that always predicts the majority class.

        Attributes
        --------------------
            prediction_ -- majority class
        """
        self.prediction_ = None

    def fit(self, X, y) :
        """
        Build a majority vote classifier from the training set (X, y).

        Parameters
        --------------------
            X    -- numpy array of shape (n,d), samples
            y    -- numpy array of shape (n,), target classes

        Returns
        --------------------
            self -- an instance of self
        """
        majority_val = Counter(y).most_common(1)[0][0]
        self.prediction_ = majority_val
        return self

    def predict(self, X) :
        """
        Predict class values.

        Parameters
        --------------------
            X    -- numpy array of shape (n,d), samples

        Returns
        --------------------
            y    -- numpy array of shape (n,), predicted classes
        """
        if self.prediction_ is None :
            raise Exception("Classifier not initialized. Perform a fit first.")

        n,d = X.shape
        y = [self.prediction_] * n
        return y

# %%
######################################################################
# Mutatble classes
######################################################################

class RandomClassifier(Classifier) :

    def __init__(self) :
        """
        A classifier that predicts according to the distribution of the classes.

        Attributes
        --------------------
            probabilities_ -- class distribution dict (key = class, val = probability of class)
        """
        self.probabilities_ = None

    def fit(self, X, y) :
        """
        Build a random classifier from the training set (X, y).

        Parameters
        --------------------
            X    -- numpy array of shape (n,d), samples
            y    -- numpy array of shape (n,), target classes

        Returns
        --------------------
            self -- an instance of self
        """

        ### ========== TODO : START ========== ###
        # part b: set self.probabilities_ according to the training set
        probs = Counter(y).most_common(2)
        print(probs)
        self.probabilities_ = {probs[0][0] : probs[0][1] / len(y) , probs[1][0]:  probs[1][1] / len(y)}
        print(self.probabilities_)
        pass

        ### ========== TODO : END ========== ###

        return self

    def predict(self, X, seed=1234) :
        """
        Predict class values.

        Parameters
        --------------------
            X    -- numpy array of shape (n,d), samples
            seed -- integer, random seed

        Returns
        --------------------
            y    -- numpy array of shape (n,), predicted classes
        """
        if self.probabilities_ is None :
            raise Exception("Classifier not initialized. Perform a fit first.")
        np.random.seed(seed)

        ### ========== TODO : START ========== ###
        # part b: predict the class for each test example
        # hint: use np.random.choice (be careful of the parameters)
        n,d = X.shape
        vals = list(self.probabilities_.keys())
        probs = list(self.probabilities_.values())
        y = np.random.choice(vals, size=n, p=probs)
        
        ### ========== TODO : END ========== ###

        return y

# %%
######################################################################
# Immutatble functions
######################################################################

def plot_histograms(X, y, Xnames, yname) :
    n,d = X.shape  # n = number of examples, d =  number of features
    fig = plt.figure(figsize=(20,15))
    ncol = 3
    nrow = d // ncol + 1
    for i in range(d) :
        fig.add_subplot (nrow,ncol,i+1)
        data, bins, align, labels = plot_histogram(X[:,i], y, Xname=Xnames[i], yname=yname, show = False)
        n, bins, patches = plt.hist(data, bins=bins, align=align, alpha=0.5, label=labels)
        plt.xlabel(Xnames[i])
        plt.ylabel('Frequency')
        plt.legend() #plt.legend(loc='upper left')

    plt.savefig ('histograms.pdf')


def plot_histogram(X, y, Xname, yname, show = True) :
    """
    Plots histogram of values in X grouped by y.

    Parameters
    --------------------
        X     -- numpy array of shape (n,d), feature values
        y     -- numpy array of shape (n,), target classes
        Xname -- string, name of feature
        yname -- string, name of target
    """

    # set up data for plotting
    targets = sorted(set(y))
    data = []; labels = []
    for target in targets :
        features = [X[i] for i in range(len(y)) if y[i] == target]
        data.append(features)
        labels.append('%s = %s' % (yname, target))

    # set up histogram bins
    features = set(X)
    nfeatures = len(features)
    test_range = list(range(int(math.floor(min(features))), int(math.ceil(max(features)))+1))
    if nfeatures < 10 and sorted(features) == test_range:
        bins = test_range + [test_range[-1] + 1] # add last bin
        align = 'left'
    else :
        bins = 10
        align = 'mid'

    # plot
    if show == True:
        plt.figure()
        n, bins, patches = plt.hist(data, bins=bins, align=align, alpha=0.5, label=labels)
        plt.xlabel(Xname)
        plt.ylabel('Frequency')
        plt.legend() #plt.legend(loc='upper left')
        plt.show()

    return data, bins, align, labels

# %%
######################################################################
# Mutatble functions
######################################################################

def error(clf, X, y, ntrials=100, test_size=0.2) :
    """
    Computes the classifier error over a random split of the data,
    averaged over ntrials runs.

    Parameters
    --------------------
        clf         -- classifier
        X           -- numpy array of shape (n,d), features values
        y           -- numpy array of shape (n,), target classes
        ntrials     -- integer, number of trials

    Returns
    --------------------
        train_error -- float, training error
        test_error  -- float, test error
        f1_score    -- float, test "micro" averaged f1 score
    """

    ### ========== TODO : START ========== ###
    # part e:
    # compute cross-validation error using StratifiedShuffleSplit over ntrials
    # hint: use StratifiedShuffleSplit (be careful of the parameters)
    splits = StratifiedShuffleSplit(n_splits=ntrials, test_size=test_size, random_state=0)
    train_errors = []
    test_errors = []
    f1_scores = []
    for train_idx, test_idx in splits.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        clf.fit(X_train, y_train)
        y_train_pred = clf.predict(X_train)
        train = 1 - metrics.accuracy_score(y_train, y_train_pred)
        
        y_test_pred = clf.predict(X_test)
        test = 1 - metrics.accuracy_score(y_test, y_test_pred)
        
        f1 = metrics.f1_score(y_test, y_test_pred, average='micro')
        
        train_errors.append(train)
        test_errors.append(test)
        f1_scores.append(f1)
    ### ========== TODO : END ========== ###
    train_error, test_error, f1_score = np.mean(train_errors), np.mean(test_errors), np.mean(f1_scores)

    return train_error, test_error, f1_score

# %%
######################################################################
# Immutatble functions
######################################################################


def write_predictions(y_pred, filename, yname=None) :
    """Write out predictions to csv file."""
    out = open(filename, 'wb')
    f = csv.writer(out)
    if yname :
        f.writerow([yname])
    f.writerows(list(zip(y_pred)))
    out.close()

# %%
######################################################################
# main
######################################################################
    
# load adult_subsample dataset with correct file path

### ========== TODO : START ========== ###
# for example data_file =  "/content/drive/My Drive/cs146/hw1/adult_subsample.csv"
data_file = "adult_subsample.csv"
### ========== TODO : END ========== ###

data = load_data(data_file, header=1, predict_col=-1)

X = data.X; Xnames = data.Xnames
y = data.y; yname = data.yname
n,d = X.shape  # n = number of examples, d =  number of features

# %%
plt.figure()
#========================================
# part a: plot histograms of each feature
print('Plotting...')
plot_histograms (X, y, Xnames=Xnames, yname=yname)
# Out:
# Plotting...

# %%
#========================================
# train Majority Vote classifier on data
print('Classifying using Majority Vote...')
clf = MajorityVoteClassifier() # create MajorityVote classifier, which includes all model parameters
clf.fit(X, y)                  # fit training data using the classifier
y_pred = clf.predict(X)        # take the classifier and run it on the training data
train_error = 1 - metrics.accuracy_score(y, y_pred, normalize=True)
print('\t-- training error: %.3f' % train_error)
# Out:
# Classifying using Majority Vote...
# ...

# %%
### ========== TODO : START ========== ###
# part b: evaluate training error of Random classifier
print('Classifying using probability Vote...')
clf = RandomClassifier()
clf.fit(X, y)
y_pred = clf.predict(X)  
train_error = 1 - metrics.accuracy_score(y, y_pred, normalize=True)
print('\t-- training error: %.3f' % train_error)
### ========== TODO : END ========== ###
# Out:
# Classifying using probability Vote...
# [(np.float64(0.0), 760), (np.float64(1.0), 240)]
# {np.float64(0.0): 0.76, np.float64(1.0): 0.24}
# 	-- training error: 0.374

# %%
### ========== TODO : START ========== ###
# part c: evaluate training error of Decision Tree classifier
model = DecisionTreeClassifier(criterion="entropy", splitter="best")
model.fit(X, y)
y_pred = model.predict(X)
train_error = 1 - metrics.accuracy_score(y, y_pred, normalize=True)
print('\t-- training error: %.3f' % train_error)

### ========== TODO : END ========== ###
# Out:
# 	-- training error: 0.000

# %%
### ========== TODO : START ========== ###
t = [3,5,7]
for i in t:
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X, y)
    y_pred = model.predict(X)
    train_error = 1 - metrics.accuracy_score(y, y_pred, normalize=True)
    print(f'\t-- training error for {i} neighbors: %.3f' % train_error)
# part d: evaluate training error of k-Nearest Neighbors classifier
# use k = 3, 5, 7 for n_neighbors
### ========== TODO : END ========== ###
# Out:
# 	-- training error for 3 neighbors: 0.153
# 	-- training error for 5 neighbors: 0.195
# 	-- training error for 7 neighbors: 0.213

# %%
### ========== TODO : START ========== ###
# part e: evaluate training error of Logistic Regression
# use lambda_ = 0.1, 1, 10 for n_neighbors
t = [0.1, 1, 10]
for i in t:
    model = LogisticRegression(random_state=0, max_iter=1000, C=1/i)
    model.fit(X, y)
    y_pred = model.predict(X)
    train_error = 1 - metrics.accuracy_score(y, y_pred, normalize=True)
    print(f'\t-- training error on KNN = {i}: %.3f' % train_error)
# Out:
# 	-- training error on KNN = 0.1: 0.180
# 	-- training error on KNN = 1: 0.185
# 	-- training error on KNN = 10: 0.181
# /Users/divikchotani/github/ece-m146/HW2-code/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/divikchotani/github/ece-m146/HW2-code/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
### ========== TODO : START ========== ###
# part f: use cross-validation to compute average training and test error of classifiers
print('Investigating various classifiers...')

dt = DecisionTreeClassifier(criterion="entropy", splitter="best")
knn =  KNeighborsClassifier(n_neighbors=5)
lr = LogisticRegression(random_state=0, max_iter=1000, C=1)



dtE= error(dt, X, y, ntrials=100,test_size=0.15)
knnE= error(knn, X, y, ntrials=100,test_size=0.15)
lrE= error(lr, X, y, ntrials=100,test_size=0.15)

print(dtE)
print(knnE)
print(lrE)
### ========== TODO : END ========== ###
# Out:
# Investigating various classifiers...
# /Users/divikchotani/github/ece-m146/HW2-code/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/divikchotani/github/ece-m146/HW2-code/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
### ========== TODO : START ========== ###
# part g: use 5-fold cross-validation to find the best value of k for k-Nearest Neighbors classifier
print('Finding the best k...')
numNeighbors = []
score = []
for i in range (1, 51):
    numNeighbors.append(i)
    knn =  KNeighborsClassifier(n_neighbors=i)
    s = cross_val_score(knn, X=X, y=y,cv=5, scoring='accuracy')
    score.append(np.mean(s))
    
best_k = numNeighbors[np.argmax(score)]
best_score = np.max(score)

print(f"The best value for k is {best_k} with a cross-validation accuracy of {best_score}")
plt.figure(figsize=(8,6))
plt.plot(numNeighbors, score, marker='X')
plt.xlabel('Number of Neighbors k')
plt.ylabel('Cross-Validation Accuracy')
plt.title('Validation Score vs. Number of Neighbors')
plt.grid(True)
plt.show()

### ========== TODO : END ========== ###
# Out:
# Finding the best k...
# The best value for k is 17 with a cross-validation accuracy of 0.7609999999999999

# %%
### ========== TODO : START ========== ###
# part h: investigate decision tree classifier with various depths
print('Investigating depths...')
depth = []
training_error = []
val_errors = []

for i in range(1, 21):
    depth.append(i)

    dt = DecisionTreeClassifier(criterion="entropy", splitter="best", max_depth=i)
    dt.fit(X, y)

    y_train_pred = dt.predict(X)
    train_accuracy = np.mean(y_train_pred == y)
    train_error = 1 - train_accuracy
    training_error.append(train_error)

    s = cross_val_score(dt, X=X, y=y, cv=5, scoring='accuracy')
    val_accuracy = np.mean(s)
    val_error = 1 - val_accuracy
    val_errors.append(val_error)

best_depth = depth[np.argmin(val_errors)]
best_score = 1 - val_errors[np.argmin(val_errors)]

print(f'Best depth: {best_depth} with validation accuracy: {best_score:.3f}')

plt.figure(figsize=(8, 6))
plt.plot(depth, training_error, marker='o', label='Training Error')
plt.plot(depth, val_errors, marker='x', label='Validation Error')
plt.xlabel('Depth Value')
plt.ylabel('Error')
plt.title('Training and Validation Error vs Tree Depth')
plt.legend()
plt.grid(True)
plt.show()


### ========== TODO : END ========== ###
# Out:
# Investigating depths...
# Best depth: 5 with validation accuracy: 0.834

# %%
print('Done')
